# %% [markdown]
# <a href="https://colab.research.google.com/github/Devraj-prasad07/python-for-data-analysis/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing Pandas in Colab Notebook

# %%
# !pip install pandas

# %% [markdown]
# Importing Pandas as Pd
#
# ---

# %%
import pandas as pd

# %% [markdown]
# Expolring Series in Pandas

# %%
data = [1,2,3,4,5]
series = pd.Series(data)
print(series)

# %%
data = {'a':1,'b':2,'c':3,'d':4,'e':5}
series = pd.Series(data)
print(series)

# %%
data = [10,20,30]
index = ['a','b','c']
series = pd.Series(data,index=index)
print(series)

# %% [markdown]
# Exploring Dataframe Df

# %%
from os import name
data = {
    'name':['Alice','Bob','Claire'],
    'age' : [25,30,27],
    'gender' : ['Female','Male','Female']
}
df = pd.DataFrame(data)
print(df)
print(type(df))

# %%
df = pd.read_csv('/02. data.csv')
df.head(5)

# %%
df.loc[1]

# %%
df.iloc[1]

# %%
df.at[2,'Region']

# %%
df.iat[2,5]

# %%
df.describe()

# %%
df.dtypes

# %% [markdown]
# Handling Missing Values

# %%
df.isnull().any()

# %%
df.isnull().sum()

# %%
df['SalesFillNA'] = df['Sales'].fillna(df['Sales'].mean())
df

# %%
df = df.rename(columns={'Date' : 'SalesDate'})
df.head(5)

# %%
groupedBy = df.groupby('product').mean
